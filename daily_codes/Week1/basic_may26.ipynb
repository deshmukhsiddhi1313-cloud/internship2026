# %%
# string functions

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name
# Out:
# 'Nitish'

# %%
name = name.lower()

# %%
name
# Out:
# 'nitish'

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
name = "Nitish"

# %%
name.swapcase()
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name3.isalnum()
# Out:
# True

# %%
name = " Pune "

# %%
print(name)
# Out:
#  Pune
